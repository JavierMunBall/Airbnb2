# %%
import pandas as pd
df = pd.read_csv("C:/Users/newmo/Desktop/Bootcamp Data/Curso/Temario/Modulo_3/Scripts, APIs, Streamlit/airbnb2/data/listings_preparado.csv")

# %%
df
# Out:
#                        id                                               name  \
# 0                   11508  Condo in Buenos Aires · ★4.81 · 1 bedroom · 1 ...
# 1                   14222  Rental unit in Palermo/Buenos Aires · ★4.79 · ...
# 2                   15074  Rental unit in Buenos Aires · 1 bedroom · 1 be...
# 3                   16695  Loft in Buenos Aires · ★4.28 · 1 bedroom · 1 b...
# 4                   20062  Rental unit in Buenos Aires · ★4.93 · 2 bedroo...
# ...                   ...                                                ...
# 29292  985617215327136942  Rental unit in Buenos Aires · ★New · 1 bedroom...
# 29293  985646171568232193  Rental unit in Buenos Aires · ★New · 1 bedroom...
# 29294  985655156094686700  Rental unit in Buenos Aires · ★New · 1 bedroom...
# 29295  985661189947878803  Rental unit in Buenos Aires · ★New · 1 bedroom...
# 29296  985661520707875805  Rental unit in Buenos Aires · ★New · Studio · ...
#
# ...

# %%
from pycaret.regression import *

# %%
df.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood', 'latitude',
#        'longitude', 'room_type', 'price', 'minimum_nights',
#        'number_of_reviews', 'last_review', 'reviews_per_month',
#        'calculated_host_listings_count', 'availability_365',
#        'number_of_reviews_ltm', 'license', 'property_type', 'accommodates',
#        'first_review', 'review_scores_value', 'review_scores_cleanliness',
#        'review_scores_location', 'review_scores_accuracy',
#        'review_scores_communication', 'review_scores_checkin',
#        'review_scores_rating', 'maximum_nights', 'listing_url',
#        'host_is_superhost', 'host_about', 'host_response_time',
#        'host_response_rate', 'listing_url.1'],
#       dtype='object')

# %%
df_pred = df.copy()
df_pred_new = df_pred[["neighbourhood","accommodates", "property_type", "room_type", "price", "minimum_nights", "maximum_nights" ]]

# %%
df_pred_new.head()
# Out:
#   neighbourhood  accommodates                property_type        room_type  \
# 0       Palermo             2                 Entire condo  Entire home/apt
# 1       Palermo             2           Entire rental unit  Entire home/apt
# 2         Nuñez             1  Private room in rental unit     Private room
# 3     Monserrat             4                  Entire loft  Entire home/apt
# 4       Palermo             4           Entire rental unit  Entire home/apt
#
#      price  minimum_nights  maximum_nights
# 0  64.1331               3            1125
# 1  32.2056               7             100
# 2  28.3527              29             730
# 3  47.2527               2            1125
# 4  96.2658               2             365

# %%
setup = setup(df_pred_new, target = "price")
# Out:
# <style type="text/css">
# #T_a1053_row9_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_a1053">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a1053_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_a1053_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a1053_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a1053_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_a1053_row0_col1" class="data row0 col1" >7560</td>
#     </tr>
#     <tr>
#       <th id="T_a1053_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_a1053_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_a1053_row1_col1" class="data row1 col1" >price</td>
#     </tr>
#     <tr>
#       <th id="T_a1053_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
best = compare_models()

# %%
ridge = create_model("ridge")
# Out:
# <style type="text/css">
# #T_d1bb0_row10_col0, #T_d1bb0_row10_col1, #T_d1bb0_row10_col2, #T_d1bb0_row10_col3, #T_d1bb0_row10_col4, #T_d1bb0_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_d1bb0">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d1bb0_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_d1bb0_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_d1bb0_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_d1bb0_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_d1bb0_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_d1bb0_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
# ...

# %%
tuned_ridge = tune_model(ridge)
# Out:
# <style type="text/css">
# #T_26653_row10_col0, #T_26653_row10_col1, #T_26653_row10_col2, #T_26653_row10_col3, #T_26653_row10_col4, #T_26653_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_26653">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_26653_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_26653_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_26653_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_26653_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_26653_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_26653_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
# ...

# %%
evaluate_model(tuned_ridge)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
final_ridge_best = finalize_model(tuned_ridge)

# %%
save_model(tuned_ridge, "ml_airbnb")
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=Memory(location=None),
#           steps=[('numerical_imputer',
#                   TransformerWrapper(include=['accommodates', 'minimum_nights',
#                                               'maximum_nights'],
#                                      transformer=SimpleImputer())),
#                  ('categorical_imputer',
#                   TransformerWrapper(include=['neighbourhood', 'property_type',
#                                               'room_type'],
#                                      transformer=SimpleImputer(strategy='most_frequent'))),
#                  ('onehot_encoding',
#                   Transfo...ype'],
#                                      transformer=OneHotEncoder(cols=['room_type'],
#                                                                handle_missing='return_nan',
#                                                                use_cat_names=True))),
# ...
